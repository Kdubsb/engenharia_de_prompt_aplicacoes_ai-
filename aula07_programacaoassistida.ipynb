# %% [markdown]
# <a href="https://colab.research.google.com/github/Kdubsb/engenharia_de_prompt_aplicacoes_ai-/blob/main/aula07_programacaoassistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #aula: Programação Assistida
# #Nome: Carlos Eduardo Andrade do Nascimento (Turma sextou)

# %%
numeros=[1,2,3,4]
# Inicializa la variable 'soma' (suma) en 0
soma = 0
# Inicializa un contador 'i' en 0, usado para acceder a los elementos por índice
i= 0
# Itera sobre cada número en la lista 'numeros'
for num in numeros:
  # Suma el número actual (usando el índice 'i') a 'soma'
  soma+=numeros[i]
  # Incrementa el contador 'i' para el siguiente elemento
  i+=1
# Imprime el resultado final de la suma
print(soma)
# Out:
# 3
